# %%
import pandas as pd

# %%
test = pd.read_csv('Electric_Vehicle_Population_Data.csv')
display(test)
# Out:
#         VIN (1-10)     County          City State  Postal Code  Model Year  \
# 0       5YJ3E1EBXK       King       Seattle    WA      98178.0        2019
# 1       5YJYGDEE3L     Kitsap       Poulsbo    WA      98370.0        2020
# 2       KM8KRDAF5P     Kitsap        Olalla    WA      98359.0        2023
# 3       5UXTA6C0XM     Kitsap       Seabeck    WA      98380.0        2021
# 4       JTMAB3FV7P   Thurston       Rainier    WA      98576.0        2023
# ...            ...        ...           ...   ...          ...         ...
# 235687  1C4RJXN62R     Pierce        Tacoma    WA      98407.0        2024
# 235688  5YJSA1E28J  Snohomish      Stanwood    WA      98292.0        2018
# 235689  3FA6P0SU2F       King       Redmond    WA      98052.0        2015
# 235690  WA1BCBFZ6P  Snohomish  Lake Stevens    WA      98258.0        2023
# 235691  WBY33AW03P       King      Issaquah    WA      98027.0        2023
#
# ...

# %%
test2 = pd.read_csv('Air_Quality.csv')
display(test2)
# Out:
#        Unique ID  Indicator ID                    Name Measure Measure Info  \
# 0         336867           375  Nitrogen dioxide (NO2)    Mean          ppb
# 1         336741           375  Nitrogen dioxide (NO2)    Mean          ppb
# 2         550157           375  Nitrogen dioxide (NO2)    Mean          ppb
# 3         412802           375  Nitrogen dioxide (NO2)    Mean          ppb
# 4         412803           375  Nitrogen dioxide (NO2)    Mean          ppb
# ...          ...           ...                     ...     ...          ...
# 18857     165993           375  Nitrogen dioxide (NO2)    Mean          ppb
# 18858     338255           386              Ozone (O3)    Mean          ppb
# 18859     651029           386              Ozone (O3)    Mean          ppb
# 18860     667628           375  Nitrogen dioxide (NO2)    Mean          ppb
# 18861     167586           375  Nitrogen dioxide (NO2)    Mean          ppb
#
# ...

# %%
test3 = pd.read_csv('Motor_Vehicle_Registrations_Dashboard_data.csv')
display(test3)
# Out:
#       year              state       Auto      Bus      Truck  Motorcycle
# 0     1900            Alabama       40.0      0.0        0.0         0.0
# 1     1900             Alaska        0.0      0.0        0.0         0.0
# 2     1900            Arizona       20.0      0.0        0.0         0.0
# 3     1900           Arkansas       20.0      0.0        0.0         0.0
# 4     1900         California      780.0      0.0        0.0         0.0
# ...    ...                ...        ...      ...        ...         ...
# 6288  2020           Virginia  3057254.0  35463.0  4329294.0    184441.0
# 6289  2020     Washington (2)  2800370.0  24172.0  4211411.0    221448.0
# 6290  2020  West Virginia (2)   508663.0   3155.0  1102015.0     43529.0
# 6291  2020      Wisconsin (2)  1901497.0  14941.0  3423523.0    276310.0
# 6292  2020            Wyoming   191332.0   4101.0   637107.0     28488.0
#
# [6293 rows x 6 columns]

# %%
test3.dtypes
# Out:
# year            int64
# state          object
# Auto          float64
# Bus           float64
# Truck         float64
# Motorcycle    float64
# dtype: object

# %%
car = test3[test3['year'] == 2025]
display(car)
# Out:
#       year              state       Auto      Bus      Truck  Motorcycle
# 0     2025            Alabama       40.0      0.0        0.0         0.0
# 1     2025             Alaska        0.0      0.0        0.0         0.0
# 2     2025            Arizona       20.0      0.0        0.0         0.0
# 3     2025           Arkansas       20.0      0.0        0.0         0.0
# 4     2025         California      780.0      0.0        0.0         0.0
# ...    ...                ...        ...      ...        ...         ...
# 6288  2025           Virginia  3057254.0  35463.0  4329294.0    184441.0
# 6289  2025     Washington (2)  2800370.0  24172.0  4211411.0    221448.0
# 6290  2025  West Virginia (2)   508663.0   3155.0  1102015.0     43529.0
# 6291  2025      Wisconsin (2)  1901497.0  14941.0  3423523.0    276310.0
# 6292  2025            Wyoming   191332.0   4101.0   637107.0     28488.0
#
# [6293 rows x 6 columns]

# %%
test4 = pd.read_csv('Air_Quality_Measures_on_the_National_Environmental_Health_Tracking_Network.csv')
display(test4)
# Out:
#         MeasureId                                        MeasureName  \
# 0              83  Number of days with maximum 8-hour average ozo...
# 1              83  Number of days with maximum 8-hour average ozo...
# 2              83  Number of days with maximum 8-hour average ozo...
# 3              83  Number of days with maximum 8-hour average ozo...
# 4              83  Number of days with maximum 8-hour average ozo...
# ...           ...                                                ...
# 218630        296  Annual average ambient concentrations of PM 2....
# 218631        296  Annual average ambient concentrations of PM 2....
# 218632        296  Annual average ambient concentrations of PM 2....
# 218633        296  Annual average ambient concentrations of PM 2....
# 218634        296  Annual average ambient concentrations of PM 2....
#
#        MeasureType StratificationLevel  StateFips StateName  CountyFips  \
# ...

# %%
test4['ReportYear'].unique()
# Out:
# array([1999, 2013, 2006, 2002, 2003, 2011, 2007, 2008, 2004, 2009, 2012,
#        2010, 2000, 2001, 2005], dtype=int64)

# %%
hope = test4[test4['ReportYear'] == 2023]
display(hope)
# Out:
# Empty DataFrame
# Columns: [MeasureId, MeasureName, MeasureType, StratificationLevel, StateFips, StateName, CountyFips, CountyName, ReportYear, Value, Unit, UnitName, DataOrigin, MonitorOnly]
# Index: []

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("marshalpatel3558/air-quality-measures-on-nehtn")

print("Path to dataset files:", path)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 import kagglehub
#       3 # Download latest version
#       4 path = kagglehub.dataset_download("marshalpatel3558/air-quality-measures-on-nehtn")
#
# ModuleNotFoundError: No module named 'kagglehub'

# %%
test5 = pd.read_csv('Air_Quality_Measures_on_the_National_Environmental_Health_Tracking_Network.csv')
display(test5)
# Out:
#         MeasureId                                        MeasureName  \
# 0              83  Number of days with maximum 8-hour average ozo...
# 1              83  Number of days with maximum 8-hour average ozo...
# 2              83  Number of days with maximum 8-hour average ozo...
# 3              83  Number of days with maximum 8-hour average ozo...
# 4              83  Number of days with maximum 8-hour average ozo...
# ...           ...                                                ...
# 218630        296  Annual average ambient concentrations of PM 2....
# 218631        296  Annual average ambient concentrations of PM 2....
# 218632        296  Annual average ambient concentrations of PM 2....
# 218633        296  Annual average ambient concentrations of PM 2....
# 218634        296  Annual average ambient concentrations of PM 2....
#
#        MeasureType StratificationLevel  StateFips StateName  CountyFips  \
# ...

# %%
test5 = pd.read_csv('data_date.csv')
display(test5)
# Out:
#              Date                                            Country  \
# 0      2022-07-21                                            Albania
# 1      2022-07-21                                            Algeria
# 2      2022-07-21                                            Andorra
# 3      2022-07-21                                             Angola
# 4      2022-07-21                                          Argentina
# ...           ...                                                ...
# 18543  2025-04-03  United Kingdom of Great Britain and Northern I...
# 18544  2025-04-03                           United States of America
# 18545  2025-04-03                                         Uzbekistan
# 18546  2025-04-03                                            Vatican
# 18547  2025-04-03                                            Vietnam
#
#                                Status  AQI Value
# 0                                Good         14
# ...
